# %% [markdown]
# # 1. train_encoding.ipynb
# - 머신러닝하기 위해 필요한 데이터 구조 조작 클래스

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from unicodedata import category
import train_encoding

# %% [markdown]
# # 2. Data 불러오기

# %%
lunch = pd.read_csv("data/lunch_df_encoding.csv")
dinner = pd.read_csv("data/dinner_df_encoding.csv")

# %%
lunch.head()
# Out:
#      datetime  year  month  date  worker_number  real_number  vacation_number  \
# 0  2016-02-01  2016      2     1           2601         2401               50
# 1  2016-02-02  2016      2     2           2601         2378               50
# 2  2016-02-03  2016      2     3           2601         2365               56
# 3  2016-02-04  2016      2     4           2601         2277              104
# 4  2016-02-05  2016      2     5           2601         2142              278
#
#    biztrip_number  overtime_number  telecom_number  ...  season_winter  \
# 0             150              238               0  ...              1
# 1             173              319               0  ...              1
# 2             180              111               0  ...              1
# 3             220              355               0  ...              1
# 4             181               34               0  ...              1
#
# ...

# %%
dinner.head()
# Out:
#      datetime  year  month  date  worker_number  real_number  vacation_number  \
# 0  2016-02-01  2016      2     1           2601         2401               50
# 1  2016-02-02  2016      2     2           2601         2378               50
# 2  2016-02-03  2016      2     3           2601         2365               56
# 3  2016-02-04  2016      2     4           2601         2277              104
# 4  2016-02-05  2016      2     5           2601         2142              278
#
#    biztrip_number  overtime_number  telecom_number  ...  season_winter  \
# 0             150              238               0  ...              1
# 1             173              319               0  ...              1
# 2             180              111               0  ...              1
# 3             220              355               0  ...              1
# 4             181               34               0  ...              1
#
# ...

# %% [markdown]
# # 3. class 호출 및 테스트

# %%
encoding = train_encoding.Train_Encoding(lunch, dinner)

# %% [markdown]
# ### 1. dropna
# - ok

# %%
dropna_lunch = encoding.dropna_lunch()
dropna_dinner = encoding.dropna_dinner()

# %%
dropna_lunch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1203 entries, 0 to 1204
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   datetime               1203 non-null   object
#  1   year                   1203 non-null   int64
#  2   month                  1203 non-null   int64
#  3   date                   1203 non-null   int64
#  4   worker_number          1203 non-null   int64
#  5   real_number            1203 non-null   int64
#  6   vacation_number        1203 non-null   int64
#  7   biztrip_number         1203 non-null   int64
#  8   overtime_number        1203 non-null   int64
#  9   telecom_number         1203 non-null   int64
#  10  temperature            1203 non-null   float64
#  11  rain                   1203 non-null   float64
#  12  wind                   1203 non-null   float64
#  13  humidity               1203 non-null   float64
# ...

# %%
dropna_dinner.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1203 entries, 0 to 1204
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   datetime               1203 non-null   object
#  1   year                   1203 non-null   int64
#  2   month                  1203 non-null   int64
#  3   date                   1203 non-null   int64
#  4   worker_number          1203 non-null   int64
#  5   real_number            1203 non-null   int64
#  6   vacation_number        1203 non-null   int64
#  7   biztrip_number         1203 non-null   int64
#  8   overtime_number        1203 non-null   int64
#  9   telecom_number         1203 non-null   int64
#  10  temperature            1203 non-null   float64
#  11  rain                   1203 non-null   float64
#  12  wind                   1203 non-null   float64
#  13  humidity               1203 non-null   float64
# ...

# %% [markdown]
# ### 2. split
# - ok

# %%
lunch_X_train, lunch_X_test, lunch_y_train, lunch_y_test = encoding.split_lunch()
dinner_X_train, dinner_X_test, dinner_y_train, dinner_y_test = encoding.split_dinner()

# %%
lunch_X_test
# Out:
#         datetime  year  month  date  worker_number  real_number  \
# 224   2016-12-28  2016     12    28           2705         2314
# 108   2016-07-12  2016      7    12           2643         2348
# 904   2019-10-18  2019     10    18           3121         2489
# 193   2016-11-15  2016     11    15           2689         2350
# 631   2018-08-27  2018      8    27           2996         2632
# ...          ...   ...    ...   ...            ...          ...
# 435   2017-11-09  2017     11     9           2644         2267
# 134   2016-08-18  2016      8    18           2644         2155
# 391   2017-08-31  2017      8    31           2645         2254
# 35    2016-03-25  2016      3    25           2624         2251
# 1162  2020-11-19  2020     11    19           3021         2490
#
#       vacation_number  biztrip_number  overtime_number  telecom_number  ...  \
# 224               166             225                0               0  ...
# ...

# %% [markdown]
# ### 3. format

# %%
lunch_X_train, lunch_X_test, dinner_X_train, dinner_X_test = encoding.format()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/dx/ny9cjsmd1bb3r42zbp694xkh0000gn/T/ipykernel_4087/2738472124.py in <module>
# ----> 1 lunch_X_train, lunch_X_test, dinner_X_train, dinner_X_test = encoding.format()
#
# ~/Desktop/Data/vscode/team_project/Forecast_final/module/train_encoding.py in format(self)
#      45         data_list = [lunch_X_train, lunch_X_test, dinner_X_train, dinner_X_test]
#      46         for data in data_list:
# ---> 47             data['year'] = data['year'].astype(category)
#      48             data['month'] = data['month'].astype(category)
#      49             data['date'] = data['date'].astype(category)
#
# ~/miniforge3/envs/ML/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# ...
